# %%
import boto3
import sagemaker
from sagemaker import get_execution_role
import logging, sys

role = get_execution_role()
account_id = role.split(":")[4]
aws_region = boto3.Session().region_name
sagemaker_session = sagemaker.session.Session()
bucket = sagemaker_session.default_bucket()
IMAGE = "load-data-opensearch-custom"
IMAGE_TAG = "latest"
docker_path = "/home/ec2-user/SageMaker/opensearch-processing-container/docker"
logger = logging.getLogger()
logging.basicConfig(format='%(asctime)s,%(module)s,%(processName)s,%(levelname)s,%(message)s', level=logging.INFO, stream=sys.stderr)

print(account_id)
print(aws_region)
print(role)
print(bucket)
# Out:
# 613526579489
# us-east-1
# arn:aws:iam::613526579489:role/semantic-search-Role-1SLQC07M4DSJJ
# sagemaker-us-east-1-613526579489

# %%
# Run script to build docker custom containe image and push it to ECR 
# Set region and sagemaker URI variables 
# Make sure the execution role has permission for ECR
session = boto3.session.Session()
client = boto3.client("sts")
account_id = client.get_caller_identity()["Account"]
logger.info(f"region={aws_region}, account_id={account_id}")
# !bash scripts/build_and_push.sh $docker_path $IMAGE $IMAGE_TAG $aws_region
# Out:
# 2023-08-15 10:58:28,467,4230248969,MainProcess,INFO,region=us-east-1, account_id=613526579489
# [08-15 10:58:29]: the full image name would be 613526579489.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest
# [08-15 10:58:30]: creating ECR repository : 613526579489.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest
# [08-15 10:58:30]: going to start a docker build, image=load-data-opensearch-custom, using Dockerfile=/home/ec2-user/SageMaker/opensearch-processing-container/docker
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (2/3)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
# [+] Building 0.3s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  0.1s
# [+] Building 0.5s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  0.3s
# [+] Building 0.6s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  0.4s
# [+] Building 0.8s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  0.6s
# [+] Building 0.9s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  0.7s
# [+] Building 1.1s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  0.9s
# [+] Building 1.2s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.0s
#  => => # adata
#  => => #   Downloading unstructured-0.9.3-py3-none-any.whl.metadata (22 kB)
#  => => # Collecting pdf2image==1.16.3
#  => => #   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
#  => => # Collecting pdfminer==20191125
#  => => #   Downloading pdfminer-20191125.tar.gz (4.2 MB)
# [+] Building 1.4s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.2s
#  => => # Collecting pdf2image==1.16.3
#  => => #   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
#  => => # Collecting pdfminer==20191125
#  => => #   Downloading pdfminer-20191125.tar.gz (4.2 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.2 MB/s eta
#  => => #  0:00:00
# [+] Building 1.5s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.3s
#  => => #   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
#  => => # Collecting pdfminer==20191125
#  => => #   Downloading pdfminer-20191125.tar.gz (4.2 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.2 MB/s eta
#  => => #  0:00:00
#  => => #   Preparing metadata (setup.py): started
# [+] Building 1.7s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.5s
#  => => # Collecting pdfminer==20191125
#  => => #   Downloading pdfminer-20191125.tar.gz (4.2 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 56.2 MB/s eta
#  => => #  0:00:00
#  => => #   Preparing metadata (setup.py): started
#  => => #   Preparing metadata (setup.py): finished with status 'done'
# [+] Building 1.8s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.6s
#  => => # onhosted.org/packages/38/6f/f5fbc992a329ee4e0f288c1fe0e2ad9485ed064cac
#  => => # 731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#  => => #   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
#  => => # Collecting filetype (from unstructured==0.9.3)
#  => => #   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
#  => => # Collecting python-magic (from unstructured==0.9.3)
# [+] Building 1.9s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.8s
#  => => # 731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#  => => #   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
#  => => # Collecting filetype (from unstructured==0.9.3)
#  => => #   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
#  => => # Collecting python-magic (from unstructured==0.9.3)
#  => => #   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# [+] Building 2.1s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  1.9s
#  => => # 731ed2fe47dcc38cbf/chardet-5.2.0-py3-none-any.whl.metadata
#  => => #   Downloading chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
#  => => # Collecting filetype (from unstructured==0.9.3)
#  => => #   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
#  => => # Collecting python-magic (from unstructured==0.9.3)
#  => => #   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# [+] Building 2.2s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.0s
#  => => # (3.8 kB)
#  => => # Collecting nltk (from unstructured==0.9.3)
#  => => #   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 97.6 MB/s eta
#  => => #  0:00:00
#  => => # Collecting tabulate (from unstructured==0.9.3)
# [+] Building 2.3s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.2s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 2.5s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.3s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 2.6s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.5s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 2.8s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.6s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 2.9s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.8s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 3.1s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  2.9s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 3.2s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  3.1s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 3.4s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  3.2s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 3.5s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  3.4s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 3.7s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  3.5s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 3.8s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  3.7s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 4.0s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  3.8s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 4.1s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  4.0s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 4.3s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  4.1s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 4.4s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  4.3s
#  => => # 3.9/site-packages (from unstructured==0.9.3) (4.12.2)
#  => => # Collecting emoji (from unstructured==0.9.3)
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
# [+] Building 4.6s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  4.4s
#  => => #   Downloading emoji-2.7.0.tar.gz (361 kB)
#  => => #      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 361.8/361.8 kB 54.0 MB/s e
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
#  => => #   Installing build dependencies: finished with status 'done'
#  => => #   Getting requirements to build wheel: started
# [+] Building 4.7s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer=  4.6s
#  => => # ta 0:00:00
#  => => #   Installing build dependencies: started
#  => => #   Installing build dependencies: finished with status 'done'
#  => => #   Getting requirements to build wheel: started
#  => => #   Getting requirements to build wheel: finished with status 'done'
#  => => #   Preparing metadata (pyproject.toml): started
# ...
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  32.9s
#  => => # 91125 pillow-10.0.0 pycryptodome-3.18.0 python-magic-0.4.27 regex-2023
#  => => # .8.8 tabulate-0.9.0 unstructured-0.9.3
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 33.2s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.0s
#  => => # 91125 pillow-10.0.0 pycryptodome-3.18.0 python-magic-0.4.27 regex-2023
#  => => # .8.8 tabulate-0.9.0 unstructured-0.9.3
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 33.3s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.2s
#  => => # 91125 pillow-10.0.0 pycryptodome-3.18.0 python-magic-0.4.27 regex-2023
#  => => # .8.8 tabulate-0.9.0 unstructured-0.9.3
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 33.5s (9/12)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => => # 91125 pillow-10.0.0 pycryptodome-3.18.0 python-magic-0.4.27 regex-2023
#  => => # .8.8 tabulate-0.9.0 unstructured-0.9.3
#  => => # WARNING: Running pip as the 'root' user can result in broken permissio
#  => => # ns and conflicting behaviour with the system package manager. It is re
#  => => # commended to use a virtual environment instead: https://pip.pypa.io/wa
#  => => # rnings/venv
# [+] Building 33.6s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => [7/8] ADD credentials.py /code/                                        0.0s
#  => [8/8] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#
#
# [+] Building 33.7s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => [7/8] ADD credentials.py /code/                                        0.0s
#  => [8/8] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 33.9s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => [7/8] ADD credentials.py /code/                                        0.0s
#  => [8/8] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 34.0s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => [7/8] ADD credentials.py /code/                                        0.0s
#  => [8/8] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 34.2s (12/13)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => [7/8] ADD credentials.py /code/                                        0.0s
#  => [8/8] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 34.3s (13/13) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 1.37kB                                     0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load metadata for docker.io/library/python:3.9-slim-buster  0.1s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 68B                                           0.0s
#  => [1/8] FROM docker.io/library/python:3.9-slim-buster@sha256:320a7a4250  0.0s
#  => CACHED [2/8] RUN apt-get -y update && apt-get install -y --no-install  0.0s
#  => CACHED [3/8] RUN ln -s /usr/bin/python3 /usr/bin/python                0.0s
#  => CACHED [4/8] RUN pip install --upgrade pip                             0.0s
#  => CACHED [5/8] RUN pip --no-cache-dir install  langchain==0.0.149 opens  0.0s
#  => [6/8] RUN pip install unstructured==0.9.3 pdf2image==1.16.3 pdfminer  33.3s
#  => [7/8] ADD credentials.py /code/                                        0.0s
#  => [8/8] ADD sm_helper.py /code/                                          0.0s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
#  => => writing image sha256:1b86855d3e3995b743ee5363c63b4a9e8e8aeb7dfb2b9  0.0s
#  => => naming to docker.io/library/load-data-opensearch-custom             0.0s
# [08-15 10:59:05]: load-data-opensearch-custom created
# [08-15 10:59:05]: going to run "aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 613526579489.dkr.ecr.us-east-1.amazonaws.com" to login to ECR
#
# Unknown options: |,docker,login,--username,AWS,--password-stdin,613526579489.dkr.ecr.us-east-1.amazonaws.com
# [08-15 10:59:06]: going to run "docker push 613526579489.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest" to push image to ecr
# The push refers to repository [613526579489.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom]
#
# d0a765f5: Preparing
# 56924de0: Preparing
# 0ad68a37: Preparing
# 317ac872: Preparing
# ad3d81b0: Preparing
# c1ecb499: Preparing
# 2b309ffe: Preparing
# a27560c1: Preparing
# 037e08b3: Preparing
# eede8d6e: Preparing
# 55769c5e: Preparing
# 317ac872: Pushed   297.2MB/286.7MBlatest: digest: sha256:bb71995d92f2304a71a1cc5285cf8965fff0b8e402cb26ebb0ae05654c062422 size: 2839
# [08-15 10:59:20]: Amazon ECR URI: 613526579489.dkr.ecr.us-east-1.amazonaws.com/load-data-opensearch-custom:latest
# [08-15 10:59:20]: all done
